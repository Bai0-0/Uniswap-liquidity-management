# %%
import requests
import json

# %%
results = requests.get("https://visordata-o9v9w.ondigitalocean.app/hypervisors/allData")
results_json = json.loads(results.text)

# %%
results_json
# for y in results_json:
#     print(results_json[y])
# Out:
# {'0x032c4e67fa01f6c3b01d0903d672d73b2f8d9dce': {'baseLower': 0,
#   'baseUpper': 0,
#   'capacityUsed': 'No cap',
#   'createDate': '03 Jul, 2021',
#   'decimals0': 18,
#   'decimals1': 18,
#   'depositCap0': 1.157920892373162e+59,
#   'depositCap1': 1.157920892373162e+59,
#   'feesReinvested0': 0.0,
#   'feesReinvested1': 0.0,
#   'feesReinvestedUSD': '0',
#   'grossFeesClaimed0': 0.0,
#   'grossFeesClaimed1': 0.0,
#   'grossFeesClaimedUSD': '0',
#   'inRange': False,
#   'maxTotalSupply': 0,
#   'observationIndex': '0',
#   'poolAddress': '0xcd83055557536eff25fd0eafbc56e74a1b4260b3',
#   'poolFeesUSD': '1357579.868637176350101142063633866',
#   'poolTvlUSD': '18189709.12345066722203745031331821',
#   'returns': {'daily': {'cumFeeReturn': 0.0,
#     'feeApr': 0,
#     'feeApy': 0,
#     'totalPeriodSeconds': 0},
#    'monthly': {'cumFeeReturn': 0.0,
#     'feeApr': 0,
#     'feeApy': 0,
#     'totalPeriodSeconds': 0},
#    'weekly': {'cumFeeReturn': 0.0,
#     'feeApr': 0,
# ...

# %%
https://visordata-o9v9w.ondigitalocean.app/charts/baseRange/all
